# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from pathlib import Path

import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.metrics import pairwise
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
from sklearn.cluster import KMeans
import matplotlib.pylab as plt
import seaborn as sns
from pandas.plotting import parallel_coordinates
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster import hierarchy

# %% [markdown]
# ### In this project we're just going to explore the dataset and summarize it

# %%
ecom_purchase_df = pd.read_csv('purchases.csv', parse_dates=True)

# %%
ecom_purchase_df.head()
# Out:
#                 event_time             order_id           product_id  \
# 0  2020-04-24 11:50:39 UTC  2294359932054536986  1515966223509089906
# 1  2020-04-24 11:50:39 UTC  2294359932054536986  1515966223509089906
# 2  2020-04-24 14:37:43 UTC  2294444024058086220  2273948319057183658
# 3  2020-04-24 14:37:43 UTC  2294444024058086220  2273948319057183658
# 4  2020-04-24 19:16:21 UTC  2294584263154074236  2273948316817424439
#
#     category_id                category_code    brand   price       user_id
# 0  2.268105e+18           electronics.tablet  samsung  162.01  1.515916e+18
# 1  2.268105e+18           electronics.tablet  samsung  162.01  1.515916e+18
# 2  2.268105e+18  electronics.audio.headphone   huawei   77.52  1.515916e+18
# 3  2.268105e+18  electronics.audio.headphone   huawei   77.52  1.515916e+18
# 4  2.268105e+18                          NaN  karcher  217.57  1.515916e+18

# %%
ecom_purchase_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2633521 entries, 0 to 2633520
# Data columns (total 8 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   event_time     object
#  1   order_id       int64
#  2   product_id     int64
#  3   category_id    float64
#  4   category_code  object
#  5   brand          object
#  6   price          float64
#  7   user_id        float64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 160.7+ MB

# %%
ecom_purchase_df.isna().sum()
# Out:
# event_time             0
# order_id               0
# product_id             0
# category_id       431954
# category_code     612202
# brand             506005
# price             431954
# user_id          2069352
# dtype: int64

# %%
len(ecom_purchase_df)
# Out:
# 2633521

# %%
ecom_purchase_df.describe().T
# Out:
#                  count          mean           std           min  \
# order_id     2633521.0  2.361783e+18  1.716538e+16  2.294360e+18
# product_id   2633521.0  1.674080e+18  3.102249e+17  1.515966e+18
# category_id  2201567.0  2.273827e+18  2.353247e+16  2.268105e+18
# price        2201567.0  1.540932e+02  2.419421e+02  0.000000e+00
# user_id       564169.0  1.515916e+18  2.379057e+07  1.515916e+18
#
#                       25%           50%           75%           max
# order_id     2.348807e+18  2.353254e+18  2.383131e+18  2.388441e+18
# product_id   1.515966e+18  1.515966e+18  1.515966e+18  2.388434e+18
# category_id  2.268105e+18  2.268105e+18  2.268105e+18  2.374499e+18
# price        1.456000e+01  5.553000e+01  1.967400e+02  5.092590e+04
# user_id      1.515916e+18  1.515916e+18  1.515916e+18  1.515916e+18

# %%
len(ecom_purchase_df['category_code'].unique())
# Out:
# 511

# %%
ecom_purchase_df['event_time'] = pd.to_datetime(ecom_purchase_df['event_time'])

# %%
plt.figure(figsize=(10,4))
sns.scatterplot(x='event_time', y='price', data=ecom_purchase_df)
plt.title('Purchases made over years')
plt.tight_layout()
plt.show()

# %%
ecom_purchase_df.head()
# Out:
#                  event_time             order_id           product_id  \
# 0 2020-04-24 11:50:39+00:00  2294359932054536986  1515966223509089906
# 1 2020-04-24 11:50:39+00:00  2294359932054536986  1515966223509089906
# 2 2020-04-24 14:37:43+00:00  2294444024058086220  2273948319057183658
# 3 2020-04-24 14:37:43+00:00  2294444024058086220  2273948319057183658
# 4 2020-04-24 19:16:21+00:00  2294584263154074236  2273948316817424439
#
#     category_id                category_code    brand   price       user_id
# 0  2.268105e+18           electronics.tablet  samsung  162.01  1.515916e+18
# 1  2.268105e+18           electronics.tablet  samsung  162.01  1.515916e+18
# 2  2.268105e+18  electronics.audio.headphone   huawei   77.52  1.515916e+18
# 3  2.268105e+18  electronics.audio.headphone   huawei   77.52  1.515916e+18
# 4  2.268105e+18                          NaN  karcher  217.57  1.515916e+18

# %%
ecom_purchase_df['month'] = ecom_purchase_df['event_time'].dt.month
ecom_purchase_df['day'] = ecom_purchase_df['event_time'].dt.day
ecom_purchase_df['year'] = ecom_purchase_df['event_time'].dt.year

# %%
plt.figure(figsize=(10,4))
sns.scatterplot(x='month', y='price', data=ecom_purchase_df)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.scatterplot(x='day', y='price', data=ecom_purchase_df)
plt.tight_layout()
plt.show()

# %%
ecom_purchase_df['year'].unique()
# Out:
# array([2020, 1970], dtype=int32)

# %%
ecom_purchase_df.head()
# Out:
#                  event_time             order_id           product_id  \
# 0 2020-04-24 11:50:39+00:00  2294359932054536986  1515966223509089906
# 1 2020-04-24 11:50:39+00:00  2294359932054536986  1515966223509089906
# 2 2020-04-24 14:37:43+00:00  2294444024058086220  2273948319057183658
# 3 2020-04-24 14:37:43+00:00  2294444024058086220  2273948319057183658
# 4 2020-04-24 19:16:21+00:00  2294584263154074236  2273948316817424439
#
#     category_id                category_code    brand   price       user_id  \
# 0  2.268105e+18           electronics.tablet  samsung  162.01  1.515916e+18
# 1  2.268105e+18           electronics.tablet  samsung  162.01  1.515916e+18
# 2  2.268105e+18  electronics.audio.headphone   huawei   77.52  1.515916e+18
# 3  2.268105e+18  electronics.audio.headphone   huawei   77.52  1.515916e+18
# 4  2.268105e+18                          NaN  karcher  217.57  1.515916e+18
#
#    month  day  year
# 0      4   24  2020
# 1      4   24  2020
# 2      4   24  2020
# 3      4   24  2020
# 4      4   24  2020

# %%
ecom_purchase_df['category_code'].unique()
# Out:
# array(['electronics.tablet', 'electronics.audio.headphone', nan,
#        'furniture.kitchen.table', 'electronics.smartphone',
#        'appliances.kitchen.refrigerators', 'appliances.personal.scales',
#        'electronics.video.tv', 'computers.components.cpu',
#        'computers.notebook', 'computers.peripherals.monitor',
#        'computers.peripherals.printer', 'appliances.kitchen.kettle',
#        'computers.components.memory', 'electronics.clocks',
#        'country_yard.weather_station', 'appliances.kitchen.blender',
#        'accessories.bag', 'computers.peripherals.keyboard',
#        'computers.peripherals.mouse', 'appliances.iron',
#        'appliances.kitchen.mixer', 'electronics.telephone',
#        'appliances.kitchen.meat_grinder',
#        'appliances.personal.hair_cutter',
#        'appliances.environment.air_heater', 'kids.skates',
#        'appliances.kitchen.washer', 'appliances.kitchen.microwave',
#        'furniture.bedroom.pillow', 'appliances.environment.vacuum',
#        'appliances.environment.water_heater',
#        'furniture.living_room.shelving', 'computers.components.cooler',
#        'computers.peripherals.joystick', 'computers.network.router',
#        'computers.components.hdd', 'appliances.kitchen.hood',
#        'appliances.ironing_board', 'apparel.glove', 'stationery.battery',
#        'construction.tools.screw', 'furniture.bedroom.bed',
#        'stationery.cartrige', 'appliances.environment.air_conditioner',
#        'appliances.kitchen.grill', 'appliances.personal.massager',
#        'appliances.kitchen.toster', 'appliances.environment.fan',
#        'stationery.paper', 'computers.gaming',
#        'appliances.kitchen.coffee_machine',
#        'computers.peripherals.camera', 'computers.peripherals.scanner',
#        'furniture.living_room.chair', 'computers.components.power_supply',
#        'electronics.audio.microphone', 'apparel.trousers',
#        'medicine.tools.tonometer', 'appliances.kitchen.juicer',
#        'appliances.kitchen.oven', 'appliances.kitchen.dishwasher',
#        'apparel.shirt', 'furniture.kitchen.chair',
#        'appliances.sewing_machine', 'computers.desktop',
#        'furniture.living_room.cabinet', 'computers.components.videocards',
#        'appliances.kitchen.coffee_grinder', 'computers.ebooks',
#        'apparel.tshirt', 'electronics.audio.acoustic',
#        'auto.accessories.compressor', 'stationery.stapler', '0.02',
#        'computers.components.cdrw', 'appliances.kitchen.fryer',
#        'appliances.kitchen.steam_cooker', 'kids.toys',
#        'appliances.environment.climate',
#        'computers.components.motherboard', '38.17',
#        'country_yard.lawn_mower', 'furniture.living_room.sofa',
#        'sport.bicycle', 'apparel.sock', 'auto.accessories.videoregister',
#        '57.85', 'electronics.video.projector', 'electronics.camera.photo',
#        'sport.tennis', 'furniture.bathroom.bath',
#        'appliances.steam_cleaner', 'construction.tools.heater',
#        'electronics.camera.video', 'kids.carriage', 'sport.trainer',
#        'apparel.costume', 'construction.tools.drill', 'kids.bottles',
#        'furniture.universal.light', 'construction.components.faucet',
#        'country_yard.cultivator', 'electronics.calculator',
#        'electronics.audio.subwoofer', 'auto.accessories.alarm', '4.14',
#        'auto.accessories.anti_freeze', '0.51', '497.66',
#        'furniture.bedroom.blanket', 'sport.diving',
#        'computers.components.sound_card', 'kids.dolls',
#        'auto.accessories.player', 'accessories.umbrella',
#        'construction.tools.saw', 'construction.tools.welding',
#        'construction.tools.generator', 'sport.ski', 'kids.swing',
#        'construction.tools.pump', 'construction.tools.light',
#        'electronics.audio.dictaphone', '98.59', '13.87', '16.18', '57.87',
#        '3.89', '4.63', '29.63', '10.42', '8.10', '19.49', '6.94', '9.26',
#        '17.36', '3.45', '0.93', '0.35', '3.47', '23.15', '34.70', '33.54',
#        '0.97', '5.79', '2.29', '92.59', '1.74', '19.95', '11.55', '15.28',
#        '2.99', '8.59', '28.94', '0.67', '11.57', '1319.42', '0.81',
#        '69.44', '20.83', '69.42', '0.23', '31.23', '6.92', '1.37', '0.00',
#        '8.54', '30.09', '14.14', '18.29', '41.64', '1.83', '0.42', '0.76',
#        '9.24', '0.05', '2.78', '53.22', '1.39', '50.90', '13.66', '24.28',
#        '16.20', '1.62', '1.16', '148.13', '26.83', '26.62', '8.08',
#        'auto.accessories.radar', '83.33', '27.78', '2.31', '50.93',
#        '208.31', '80.76', 'kids.fmcg.diapers', '132.41', '74.07', '1.50',
#        '7.85', '6.71', '27.08', '34.72', '0.58', '20.81', '12.27',
#        '41.67', '46.30', '12.73', '13.89', '40.49', '87.94', '15.05',
#        '162.04', '14.12', '10.44', '18.52', '53.24', '122.66', '18.98',
#        '8.33', '9.93', '22.66', '0.46', '27.75', '22.43', '8.31', '39.33',
#        '120.98', '83.31', '5.76', '27.34', '740.54', '9.14', '23.13',
#        '37.04', '5.56', '143.50', '1.13', '4.61', '46.27', '0.44',
#        '13.91', '416.64', '11.32', '18.03', '266.18', '15.25', '33.33',
#        '179.27', '370.35', '601.60', '115.72', '97.20', '10.39', '245.93',
#        '196.74', '92.57', '35.39', '78.68', '300.90', '48.59', '32.38',
#        '12.94', '4.38', '7.38', '14.33', '55.53', '2.52', '75.22',
#        '109.83', '3.68', '62.49', '12.96', '35.86', '17.59', '16.67',
#        '138.87', '18.50', '578.68', '129.61', '1.60', '64.79', '37.60',
#        '270.67', '222.22', '590.25', '393.50', '105.31', '185.19',
#        '165.49', '856.23', '127.29', '0.69', '17.57', '7.41', '967.57',
#        '5.53', '0.21', '295.01', '37.01', '168.96', '234.94', '15.02',
#        '2.55', '810.16', '1110.86', '23.14', '260.40', '5.30', '67.13',
#        '509.24', '277.75', '173.42', '20.99', '68.04', '671.27', '115.74',
#        '104.17', '52.07', '6.23', '300.91', '134.26', '17.34', '56.69',
#        '30.07', '27.29', '108.77', '462.94', '261.55', '138.74', '62.48',
#        '13.63', '5.83', '555.53', '81.00', '472.02', '5.32', '350.67',
#        '8.77', '219.88', '694.42', '451.37', '23.33', '110.91', '28.91',
#        '3.91', '21.05', '21.53', '67.11', 'furniture.bathroom.toilet',
#        '114.58', '25.44', '335.63', '542.11', '145.81', '25.46', '395.81',
#        '12.71', '43.96', '104.14', '347.20', '324.05', '231.46', '97.04',
#        '19.68', '85.63', '810.17', '18.51', '765.91', '81.01', '22.20',
#        '11.67', '518.50', '787.01', '988.40', '289.33', '12.25', '128.68',
#        '532.38', '462.96', '6.48', '4094.91', '0.03', '43.50', '90.25',
#        '13.17', '36.34', '14.81', '138.89', '400.44', '270.82', '15.49',
#        '333.31', '26.16', '31.25', '21.74', '406.93', '9.47', '7.62',
#        '6.02', '3.94', '134.24', '413.02', '729.14', '39.58', '38.19',
#        '314.79', '32.41', '11.11', '286.44', '0.65', '55.54', '361.09',
#        '18.26', '486.09', '64.80', '46.29', '694.44', '555.30', '41.90',
#        'sport.snowboard', '55.56', 'country_yard.watering', '53.91',
#        '2.75', '7.18', '254.61', '3.56', '312.48', '24.05', '564.79',
#        '120.35', '212.94', '543.96', '368.03', '31.94', '92.34', '106.43',
#        '9.21', '24.31', '0.12', '47.89', '49.31', '69.43', '773.13',
#        '290.64', '50.21', '21.30', '34.00', '39.56', '20.86', '31.69',
#        '124.98', '37.94', '65.25', '1666.64', '61.10', '2312.50',
#        '412.01', '118.72', '185.16', '386.55', '36.09', '74.05', '226.25',
#        '162.01', '446.74', '456.00', '1.09', '1157.38', '14.56', '16.88',
#        '1.23', 'apparel.shoes', '73.59', '84.00', '432.85', '1435.16',
#        '384.24', '1354.14', '1215.25', '833.31', '41.41', '717.57',
#        '740.72', '26.60', '3.22', '6.69', '226.37', '592.57', '63.63',
#        '0.90', '493.03', '1620.35', '129.38', '2.06', '26.92', '1.15',
#        '1180.53', '310.16', '120.58', '499.98', '1388.87', '752.29',
#        '240.72', '71.74', '62.01', '789.33'], dtype=object)

# %%
ecom_purchase_df[ecom_purchase_df['category_id'].isna()]
# Out:
#                        event_time             order_id           product_id  \
# 1812    2020-05-02 11:12:20+00:00  2300138854784434309  1515966223509353669
# 3633    2020-05-06 07:37:55+00:00  2302930038149874117  1515966223509128764
# 3918    2020-05-06 22:36:13+00:00  2303382163636093788  1515966223510204743
# 6015    2020-05-10 09:41:54+00:00  2305891548316827762  1515966223509353669
# 7802    2020-05-13 03:09:39+00:00  2307868447599493180  1515966223510600539
# ...                           ...                  ...                  ...
# 2632423 2020-11-19 11:34:56+00:00  2388440981134693047  2388434452476082043
# 2632434 2020-11-19 05:38:31+00:00  2388440981134693055  1515966223523303300
# 2632437 2020-11-19 11:21:22+00:00  2388440981134693056  1515966223523303302
# 2632472 2020-11-19 09:54:22+00:00  2388440981134693073  2388434452476685318
# 2632511 2020-11-13 19:46:20+00:00  2388440981134693099  2388434452474499352
#
#          category_id category_code                brand  price  user_id  \
# 1812             NaN          0.02  1515915625453675584    NaN      NaN
# 3633             NaN         38.17  1515915625455624044    NaN      NaN
# 3918             NaN          0.02  1515915625441101795    NaN      NaN
# 6015             NaN          0.02  1515915625441980762    NaN      NaN
# 7802             NaN          0.02  1515915625441293616    NaN      NaN
# ...              ...           ...                  ...    ...      ...
# 2632423          NaN         16.18  1515915625514803713    NaN      NaN
# 2632434          NaN         13.87  1515915625514803718    NaN      NaN
# 2632437          NaN         57.87  1515915625514803719    NaN      NaN
# 2632472          NaN          5.76  1515915625514155115    NaN      NaN
# 2632511          NaN          0.00  1515915625514803864    NaN      NaN
#
#          month  day  year
# 1812         5    2  2020
# 3633         5    6  2020
# 3918         5    6  2020
# 6015         5   10  2020
# 7802         5   13  2020
# ...        ...  ...   ...
# 2632423     11   19  2020
# 2632434     11   19  2020
# 2632437     11   19  2020
# 2632472     11   19  2020
# 2632511     11   13  2020
#
# [431954 rows x 11 columns]

# %%
ecom_purchase_df.iloc[6015]
# Out:
# event_time       2020-05-10 09:41:54+00:00
# order_id               2305891548316827762
# product_id             1515966223509353669
# category_id                            NaN
# category_code                         0.02
# brand                  1515915625441980762
# price                                  NaN
# user_id                                NaN
# month                                    5
# day                                     10
# year                                  2020
# Name: 6015, dtype: object

# %%
numeric_rows = ecom_purchase_df[pd.to_numeric(ecom_purchase_df['category_code'], errors='coerce').notna()]

# %%
numeric_rows
# Out:
#                        event_time             order_id           product_id  \
# 1812    2020-05-02 11:12:20+00:00  2300138854784434309  1515966223509353669
# 3633    2020-05-06 07:37:55+00:00  2302930038149874117  1515966223509128764
# 3918    2020-05-06 22:36:13+00:00  2303382163636093788  1515966223510204743
# 6015    2020-05-10 09:41:54+00:00  2305891548316827762  1515966223509353669
# 7802    2020-05-13 03:09:39+00:00  2307868447599493180  1515966223510600539
# ...                           ...                  ...                  ...
# 2632423 2020-11-19 11:34:56+00:00  2388440981134693047  2388434452476082043
# 2632434 2020-11-19 05:38:31+00:00  2388440981134693055  1515966223523303300
# 2632437 2020-11-19 11:21:22+00:00  2388440981134693056  1515966223523303302
# 2632472 2020-11-19 09:54:22+00:00  2388440981134693073  2388434452476685318
# 2632511 2020-11-13 19:46:20+00:00  2388440981134693099  2388434452474499352
#
#          category_id category_code                brand  price  user_id  \
# 1812             NaN          0.02  1515915625453675584    NaN      NaN
# 3633             NaN         38.17  1515915625455624044    NaN      NaN
# 3918             NaN          0.02  1515915625441101795    NaN      NaN
# 6015             NaN          0.02  1515915625441980762    NaN      NaN
# 7802             NaN          0.02  1515915625441293616    NaN      NaN
# ...              ...           ...                  ...    ...      ...
# 2632423          NaN         16.18  1515915625514803713    NaN      NaN
# 2632434          NaN         13.87  1515915625514803718    NaN      NaN
# 2632437          NaN         57.87  1515915625514803719    NaN      NaN
# 2632472          NaN          5.76  1515915625514155115    NaN      NaN
# 2632511          NaN          0.00  1515915625514803864    NaN      NaN
#
#          month  day  year
# 1812         5    2  2020
# 3633         5    6  2020
# 3918         5    6  2020
# 6015         5   10  2020
# 7802         5   13  2020
# ...        ...  ...   ...
# 2632423     11   19  2020
# 2632434     11   19  2020
# 2632437     11   19  2020
# 2632472     11   19  2020
# 2632511     11   13  2020
#
# [431954 rows x 11 columns]

# %%
numeric_rows2 = ecom_purchase_df[pd.to_numeric(ecom_purchase_df['brand'], errors='coerce').notna()]

# %%
numeric_rows2
# Out:
#                        event_time             order_id           product_id  \
# 1812    2020-05-02 11:12:20+00:00  2300138854784434309  1515966223509353669
# 3633    2020-05-06 07:37:55+00:00  2302930038149874117  1515966223509128764
# 3918    2020-05-06 22:36:13+00:00  2303382163636093788  1515966223510204743
# 6015    2020-05-10 09:41:54+00:00  2305891548316827762  1515966223509353669
# 7802    2020-05-13 03:09:39+00:00  2307868447599493180  1515966223510600539
# ...                           ...                  ...                  ...
# 2632423 2020-11-19 11:34:56+00:00  2388440981134693047  2388434452476082043
# 2632434 2020-11-19 05:38:31+00:00  2388440981134693055  1515966223523303300
# 2632437 2020-11-19 11:21:22+00:00  2388440981134693056  1515966223523303302
# 2632472 2020-11-19 09:54:22+00:00  2388440981134693073  2388434452476685318
# 2632511 2020-11-13 19:46:20+00:00  2388440981134693099  2388434452474499352
#
#          category_id category_code                brand  price  user_id  \
# 1812             NaN          0.02  1515915625453675584    NaN      NaN
# 3633             NaN         38.17  1515915625455624044    NaN      NaN
# 3918             NaN          0.02  1515915625441101795    NaN      NaN
# 6015             NaN          0.02  1515915625441980762    NaN      NaN
# 7802             NaN          0.02  1515915625441293616    NaN      NaN
# ...              ...           ...                  ...    ...      ...
# 2632423          NaN         16.18  1515915625514803713    NaN      NaN
# 2632434          NaN         13.87  1515915625514803718    NaN      NaN
# 2632437          NaN         57.87  1515915625514803719    NaN      NaN
# 2632472          NaN          5.76  1515915625514155115    NaN      NaN
# 2632511          NaN          0.00  1515915625514803864    NaN      NaN
#
#          month  day  year
# 1812         5    2  2020
# 3633         5    6  2020
# 3918         5    6  2020
# 6015         5   10  2020
# 7802         5   13  2020
# ...        ...  ...   ...
# 2632423     11   19  2020
# 2632434     11   19  2020
# 2632437     11   19  2020
# 2632472     11   19  2020
# 2632511     11   13  2020
#
# [38619 rows x 11 columns]

# %%
ecom_purchase_df[ecom_purchase_df['user_id'] == 1515915625514803864]
# Out:
#                        event_time             order_id           product_id  \
# 2632488 2020-09-21 00:52:43+00:00  2388440981134693078  2388434452474163779
# 2632489 2020-09-21 01:05:31+00:00  2388440981134693079  2388434452474163779
# 2632490 2020-09-22 11:17:55+00:00  2388440981134693080  2388434452474163779
# 2632491 2020-09-26 08:26:50+00:00  2388440981134693081  2388434452474163779
# 2632503 2020-11-07 05:27:32+00:00  2388440981134693093  1515966223509106815
# ...                           ...                  ...                  ...
# 2632611 2020-11-03 23:37:24+00:00  2388440981134693179  1515966223509266995
# 2632613 2020-11-17 12:57:32+00:00  2388440981134693181  2388434452473969876
# 2632614 2020-11-18 04:40:18+00:00  2388440981134693182  2388434452476391058
# 2632615 2020-11-18 22:37:24+00:00  2388440981134693183  1515966223509301716
# 2632617 2020-11-18 02:39:38+00:00  2388440981134693185  2388434452475834029
#
#           category_id                      category_code    brand    price  \
# 2632488  2.268105e+18                      apparel.glove     sony   694.42
# 2632489  2.268105e+18                      apparel.glove     sony   694.42
# 2632490  2.268105e+18                      apparel.glove     sony   694.42
# 2632491  2.268105e+18                      apparel.glove     sony   694.42
# 2632503  2.268105e+18   appliances.kitchen.refrigerators    bosch  1319.42
# ...               ...                                ...      ...      ...
# 2632611  2.268105e+18           appliances.ironing_board  perilla    37.01
# 2632613  2.268105e+18        electronics.audio.headphone   bloody    37.01
# 2632614  2.268105e+18             electronics.smartphone   xiaomi   300.90
# 2632615  2.268105e+18  computers.components.power_supply  gamemax    68.50
# 2632617  2.268105e+18                 computers.notebook   lenovo   486.09
#
#               user_id  month  day  year
# 2632488  1.515916e+18      9   21  2020
# 2632489  1.515916e+18      9   21  2020
# 2632490  1.515916e+18      9   22  2020
# 2632491  1.515916e+18      9   26  2020
# 2632503  1.515916e+18     11    7  2020
# ...               ...    ...  ...   ...
# 2632611  1.515916e+18     11    3  2020
# 2632613  1.515916e+18     11   17  2020
# 2632614  1.515916e+18     11   18  2020
# 2632615  1.515916e+18     11   18  2020
# 2632617  1.515916e+18     11   18  2020
#
# [76 rows x 11 columns]

# %% [markdown]
# It looks like the values in the category_code and price columns have been swapped and same for brand and user_id columns
# We need to swap the float values in the category_code column to the price column and the integer values in the brand column to the
# user_id column

# %%
numeric_rows.index
# Out:
# Index([   1812,    3633,    3918,    6015,    7802,    8206,   10603,   10607,
#          11359,   11391,
#        ...
#        2632401, 2632402, 2632405, 2632412, 2632418, 2632423, 2632434, 2632437,
#        2632472, 2632511],
#       dtype='int64', length=431954)

# %%
ecom_purchase_df2 = ecom_purchase_df.copy()

# %%
ecom_purchase_df2.isna().sum()
# Out:
# event_time             0
# order_id               0
# product_id             0
# category_id       431954
# category_code     612202
# brand             506005
# price             431954
# user_id          2069352
# month                  0
# day                    0
# year                   0
# dtype: int64

# %%
ecom_purchase_df2['price'] = np.where(ecom_purchase_df2.index.isin(numeric_rows.index), numeric_rows['category_code'].reindex(ecom_purchase_df2.index), ecom_purchase_df2['price'])

# %%
ecom_purchase_df2['user_id'] = np.where(ecom_purchase_df2.index.isin(numeric_rows2.index), numeric_rows2['brand'].reindex(ecom_purchase_df2.index), ecom_purchase_df2['user_id'])

# %%
ecom_purchase_df2.isna().sum()
# Out:
# event_time             0
# order_id               0
# product_id             0
# category_id       431954
# category_code     612202
# brand             506005
# price                  0
# user_id          2030733
# month                  0
# day                    0
# year                   0
# dtype: int64

# %% [markdown]
# We're going to drop the missing values by dropping the user_id column first then the rows that has category_id, category_code and brand as null

# %%
ecom_purchase_df2.drop(['user_id'], axis=1, inplace=True)

# %%
ecom_purchase_df2.dropna(axis=0, inplace=True)

# %%
ecom_purchase_df2.isna().sum()
# Out:
# event_time       0
# order_id         0
# product_id       0
# category_id      0
# category_code    0
# brand            0
# price            0
# month            0
# day              0
# year             0
# dtype: int64

# %%
ecom_purchase_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1532175 entries, 0 to 2633520
# Data columns (total 10 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   event_time     1532175 non-null  datetime64[ns, UTC]
#  1   order_id       1532175 non-null  int64
#  2   product_id     1532175 non-null  int64
#  3   category_id    1532175 non-null  float64
#  4   category_code  1532175 non-null  object
#  5   brand          1532175 non-null  object
#  6   price          1532175 non-null  object
#  7   month          1532175 non-null  int32
#  8   day            1532175 non-null  int32
#  9   year           1532175 non-null  int32
# dtypes: datetime64[ns, UTC](1), float64(1), int32(3), int64(2), object(3)
# memory usage: 111.1+ MB

# %%
ecom_purchase_df2.head()
# Out:
#                  event_time             order_id           product_id  \
# 0 2020-04-24 11:50:39+00:00  2294359932054536986  1515966223509089906
# 1 2020-04-24 11:50:39+00:00  2294359932054536986  1515966223509089906
# 2 2020-04-24 14:37:43+00:00  2294444024058086220  2273948319057183658
# 3 2020-04-24 14:37:43+00:00  2294444024058086220  2273948319057183658
# 5 2020-04-26 08:45:57+00:00  2295716521449619559  1515966223509261697
#
#     category_id                category_code    brand   price  month  day  \
# 0  2.268105e+18           electronics.tablet  samsung  162.01      4   24
# 1  2.268105e+18           electronics.tablet  samsung  162.01      4   24
# 2  2.268105e+18  electronics.audio.headphone   huawei   77.52      4   24
# 3  2.268105e+18  electronics.audio.headphone   huawei   77.52      4   24
# 5  2.268105e+18      furniture.kitchen.table  maestro   39.33      4   26
#
#    year
# 0  2020
# 1  2020
# 2  2020
# 3  2020
# 5  2020

# %%
ecom_purchase_df2['price'] = ecom_purchase_df2['price'].astype('float')

# %% [markdown]
# Also one more thing we can observe is that there are duplicate rows in the dataframe and there are some entries which have the year
# as 1970, which can be impossible since in the description of the dataset it says that the data from from 2020 year only and by common sense too
# it's easily understandable since e-commerce didn't exist back then

# %%
ecom_purchase_df2.drop_duplicates(keep='first', inplace=True)

# %%
ecom_purchase_df2[ecom_purchase_df2['year'] == 1970]
# Out:
#                      event_time             order_id           product_id  \
# 28815 1970-01-01 00:33:40+00:00  2340102742439100830  1515966223509089955
# 28816 1970-01-01 00:33:40+00:00  2340102742439100830  1515966223509297118
# 28817 1970-01-01 00:33:40+00:00  2340102742439100830  1515966223509088552
# 28819 1970-01-01 00:33:40+00:00  2340102743319904671  1515966223509104166
# 28821 1970-01-01 00:33:40+00:00  2340102743923884448  1515966223509106168
# ...                         ...                  ...                  ...
# 55934 1970-01-01 00:33:40+00:00  2348533154999960193  1515966223509128849
# 55935 1970-01-01 00:33:40+00:00  2348533155134177922  2273948310978953267
# 55939 1970-01-01 00:33:40+00:00  2348533155671048838  1515966223509089056
# 55941 1970-01-01 00:33:40+00:00  2348533155973038728  1515966223509118608
# 55942 1970-01-01 00:33:40+00:00  2348533155973038728  1515966223509259282
#
#         category_id                      category_code     brand   price  \
# 28815  2.268105e+18    appliances.kitchen.meat_grinder  moulinex   57.85
# 28816  2.268105e+18  appliances.environment.air_heater       ava   48.59
# 28817  2.268105e+18             electronics.smartphone   samsung  196.27
# 28819  2.268105e+18             electronics.smartphone      oppo  138.87
# 28821  2.268105e+18      appliances.environment.vacuum   samsung   69.42
# ...             ...                                ...       ...     ...
# 55934  2.268105e+18           computers.network.router   tp-link   23.13
# 55935  2.268105e+18          appliances.kitchen.kettle     tefal   56.69
# 55939  2.268105e+18             electronics.smartphone      oppo  115.49
# 55941  2.268105e+18        electronics.audio.headphone    hyperx  113.40
# 55942  2.268105e+18          appliances.kitchen.washer   indesit  198.13
#
#        month  day  year
# 28815      1    1  1970
# 28816      1    1  1970
# 28817      1    1  1970
# 28819      1    1  1970
# 28821      1    1  1970
# ...      ...  ...   ...
# 55934      1    1  1970
# 55935      1    1  1970
# 55939      1    1  1970
# 55941      1    1  1970
# 55942      1    1  1970
#
# [10256 rows x 10 columns]

# %%
ecom_purchase_df_cleaned = ecom_purchase_df2[ecom_purchase_df2['year'] != 1970]

# %%
len(ecom_purchase_df_cleaned)
# Out:
# 1521419

# %%
ecom_purchase_df_cleaned.to_csv('purchase_data_cleaned2.csv', index=False)

# %% [markdown]
# # Visualizing the data

# %%
ecom_df_cleaned = pd.read_csv('purchase_data_cleaned2.csv')

# %%
ecom_df_cleaned = ecom_df_cleaned[ecom_df_cleaned['price'] > 0]

# %%
ecom_df_cleaned[ecom_df_cleaned['price'] > 50000]
# Out:
#                        event_time             order_id           product_id  \
# 614023  2020-05-26 08:12:38+00:00  2353234364520727464  1515966223509105016
#
#          category_id         category_code    brand    price  month  day  year
# 614023  2.374499e+18  electronics.video.tv  samsung  50925.9      5   26  2020

# %%
# 2. Top 10 Categories
top_categories = ecom_df_cleaned['category_code'].value_counts().head(10)

# 3. Top 10 Brands
top_brands = ecom_df_cleaned['brand'].value_counts().head(10)

# 5. Most Expensive Products
most_expensive = ecom_df_cleaned[['product_id', 'price', 'category_code', 'brand']].sort_values(by='price', ascending=False).drop_duplicates('category_code').head(10)

# 6. Cheapest Products
cheapest_products = ecom_df_cleaned[['product_id', 'price', 'category_code', 'brand']].sort_values(by='price', ascending=True).drop_duplicates('category_code').head(10)

# %%
most_expensive
# Out:
#                   product_id     price                     category_code  \
# 614023   1515966223509105016  50925.90              electronics.video.tv
# 6744     1515966223509105377   9606.48            electronics.smartphone
# 96380    2273948308655309531   9173.59  appliances.kitchen.refrigerators
# 9197     1515966223510420888   6215.25       furniture.living_room.chair
# 80819    1515966223509130727   6018.50                 computers.desktop
# 194889   1515966223509122935   5370.35                computers.notebook
# 652242   1515966223509259018   4629.58         appliances.kitchen.washer
# 1435257  2361513866753475199   4494.42                     sport.trainer
# 1029250  1515966223510522099   4259.24    computers.peripherals.keyboard
# 1299174  1515966223509881605   3654.61          electronics.camera.video
#
#              brand
# 614023     samsung
# 6744            lg
# 96380           lg
# 9197     yamaguchi
# 80819        apple
# 194889       apple
# 652242          lg
# 1435257  technogym
# 1029250     casada
# 1299174      casio

# %%
cheapest_products
# Out:
#                   product_id  price                category_code     brand
# 5729     1515966223510032494   0.02           computers.notebook      none
# 1108075  1515966223509261546   0.21                   kids.dolls  x-cooler
# 541819   2309018260231684957   0.21                apparel.glove   rossija
# 100428   1515966223510871931   0.23       electronics.smartphone       dji
# 2833     2273948282398966708   0.23  electronics.audio.headphone       sbs
# 471523   2273948185074336130   0.23  computers.components.cooler      ship
# 1509346  2273948244742505210   0.23              accessories.bag       dji
# 79145    2273948282365412223   0.23     construction.tools.light       sbs
# 1474575  2273948247737238439   0.23        electronics.telephone       dji
# 630274   1515966223509381603   0.23           stationery.stapler      hoco

# %%
ecom_df_cleaned[ecom_df_cleaned['product_id'] == 2309018260231684957]
# Out:
#                        event_time             order_id           product_id  \
# 541819  2020-07-14 04:50:31+00:00  2352855308012880346  2309018260231684957
#
#          category_id  category_code    brand  price  month  day  year
# 541819  2.268106e+18  apparel.glove  rossija   0.21      7   14  2020

# %%
# Top 10 Categories
plt.figure(figsize=(9,5))
# sns.barplot(x=top_categories.index, y=top_categories.values, hue=top_categories.index)
sns.barplot(x=top_categories.values, y=top_categories.index, hue=top_categories.index)

plt.title('Top 10 Categories by Number of Purchases')
plt.xticks(rotation=0)
plt.xlabel('Number of Purchases')
plt.ylabel('Category')
plt.tight_layout()
plt.show()

# %%
# Top 10 Brands
plt.figure(figsize=(9,5))
# sns.barplot(x=top_brands.index, y=top_brands.values, hue=top_brands.index)
sns.barplot(x=top_brands.values, y=top_brands.index, hue=top_brands.index)
plt.title('Top 10 Brands by Number of Purchases')
plt.xticks(rotation=0)
plt.xlabel('Number of Purchases')
plt.ylabel('Brand')
plt.tight_layout()
plt.show()

# %%
# Most Expensive Products
plt.figure(figsize=(9,5))
# sns.barplot(x=most_expensive['category_code'], y=most_expensive['price'], hue=most_expensive['brand'])
sns.barplot(x=most_expensive['price'], y=most_expensive['category_code'], hue=most_expensive['brand'])

plt.title('Top 10 most expensive products across each category')
plt.xticks(rotation=0)
plt.xlabel('Price')
plt.ylabel('Product')
plt.tight_layout()
plt.show()

# %%
# Cheapest Products
plt.figure(figsize=(9,5))
# sns.barplot(x=cheapest_products['category_code'], y=cheapest_products['price'], hue=cheapest_products['brand'])
sns.barplot(x=cheapest_products['price'], y=cheapest_products['category_code'], hue=cheapest_products['brand'])

plt.title('Top 10 cheapest products across each category')
plt.xticks(rotation=0)
plt.xlabel('Price')
plt.ylabel('Product')
plt.tight_layout()
plt.show()

# %%
ecom_df_cleaned.head()
# Out:
#                   event_time             order_id           product_id  \
# 0  2020-04-24 11:50:39+00:00  2294359932054536986  1515966223509089906
# 1  2020-04-24 14:37:43+00:00  2294444024058086220  2273948319057183658
# 2  2020-04-26 08:45:57+00:00  2295716521449619559  1515966223509261697
# 3  2020-04-26 09:33:47+00:00  2295740594749702229  1515966223509104892
# 4  2020-04-26 14:55:26+00:00  2295902490203259134  2273948311742316796
#
#     category_id                     category_code    brand    price  month  \
# 0  2.268105e+18                electronics.tablet  samsung   162.01      4
# 1  2.268105e+18       electronics.audio.headphone   huawei    77.52      4
# 2  2.268105e+18           furniture.kitchen.table  maestro    39.33      4
# 3  2.268105e+18            electronics.smartphone    apple  1387.01      4
# 4  2.268105e+18  appliances.kitchen.refrigerators       lg   462.94      4
#
#    day  year
# 0   24  2020
# 1   24  2020
# 2   26  2020
# 3   26  2020
# 4   26  2020

# %%
plt.figure(figsize=(9,5))
sns.countplot(x='month', data=ecom_df_cleaned)
plt.title('Total Products sold across each month')
plt.xticks(rotation=0)
plt.xlabel('Months')
plt.ylabel('Number of Products Sold')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Clustering

# %% [markdown]
# ### Kmeans Clustering

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
ecom_df_cleaned = pd.read_csv('purchase_data_cleaned2.csv')

# %%
ecom_df_cleaned.head()
# Out:
#                   event_time             order_id           product_id  \
# 0  2020-04-24 11:50:39+00:00  2294359932054536986  1515966223509089906
# 1  2020-04-24 14:37:43+00:00  2294444024058086220  2273948319057183658
# 2  2020-04-26 08:45:57+00:00  2295716521449619559  1515966223509261697
# 3  2020-04-26 09:33:47+00:00  2295740594749702229  1515966223509104892
# 4  2020-04-26 14:55:26+00:00  2295902490203259134  2273948311742316796
#
#     category_id                     category_code    brand    price  month  \
# 0  2.268105e+18                electronics.tablet  samsung   162.01      4
# 1  2.268105e+18       electronics.audio.headphone   huawei    77.52      4
# 2  2.268105e+18           furniture.kitchen.table  maestro    39.33      4
# 3  2.268105e+18            electronics.smartphone    apple  1387.01      4
# 4  2.268105e+18  appliances.kitchen.refrigerators       lg   462.94      4
#
#    day  year
# 0   24  2020
# 1   24  2020
# 2   26  2020
# 3   26  2020
# 4   26  2020

# %%
ecom_df_cleaned.describe().T
# Out:
#                  count          mean           std           min  \
# order_id     1521419.0  2.362576e+18  1.745477e+16  2.294360e+18
# product_id   1521419.0  1.676797e+18  3.127019e+17  1.515966e+18
# category_id  1521419.0  2.275808e+18  2.705632e+16  2.268105e+18
# price        1521419.0  1.962994e+02  2.629316e+02  0.000000e+00
# month        1521419.0  5.744970e+00  2.918679e+00  1.000000e+00
# day          1521419.0  1.560595e+01  8.714624e+00  1.000000e+00
# year         1521419.0  2.020000e+03  0.000000e+00  2.020000e+03
#
#                       25%           50%           75%           max
# order_id     2.348815e+18  2.353264e+18  2.383856e+18  2.388441e+18
# product_id   1.515966e+18  1.515966e+18  1.515966e+18  2.388434e+18
# category_id  2.268105e+18  2.268105e+18  2.268105e+18  2.374499e+18
# price        2.914000e+01  1.154900e+02  2.569200e+02  5.092590e+04
# month        3.000000e+00  6.000000e+00  8.000000e+00  1.100000e+01
# day          8.000000e+00  1.600000e+01  2.300000e+01  3.100000e+01
# year         2.020000e+03  2.020000e+03  2.020000e+03  2.020000e+03

# %%
# dropping the event_time column because we've already extracted the mo|nth, year and day from it. 
ecom_df_cleaned = ecom_df_cleaned.drop(['event_time'], axis=1)

# %%
ecom_df_cleaned.head()
# Out:
#               order_id           product_id   category_id  \
# 0  2294359932054536986  1515966223509089906  2.268105e+18
# 1  2294444024058086220  2273948319057183658  2.268105e+18
# 2  2295716521449619559  1515966223509261697  2.268105e+18
# 3  2295740594749702229  1515966223509104892  2.268105e+18
# 4  2295902490203259134  2273948311742316796  2.268105e+18
#
#                       category_code    brand    price  month  day  year
# 0                electronics.tablet  samsung   162.01      4   24  2020
# 1       electronics.audio.headphone   huawei    77.52      4   24  2020
# 2           furniture.kitchen.table  maestro    39.33      4   26  2020
# 3            electronics.smartphone    apple  1387.01      4   26  2020
# 4  appliances.kitchen.refrigerators       lg   462.94      4   26  2020

# %%
# converting categorical columns into numerical. We can also drop category_id column since the id's are duplicated and seem odd
ecom_df_cleaned = ecom_df_cleaned.drop(['category_id'], axis=1)

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder_category = LabelEncoder()
label_encoder_brand = LabelEncoder()

# Apply Label Encoding
ecom_df_cleaned['category_code'] = label_encoder_category.fit_transform(ecom_df_cleaned['category_code'])
ecom_df_cleaned['brand'] = label_encoder_brand.fit_transform(ecom_df_cleaned['brand'])

# %%
ecom_df_cleaned.head()
# Out:
#               order_id           product_id  category_code  brand    price  \
# 0  2294359932054536986  1515966223509089906             89    458   162.01
# 1  2294444024058086220  2273948319057183658             81    243    77.52
# 2  2295716521449619559  1515966223509261697             99    323    39.33
# 3  2295740594749702229  1515966223509104892             88     32  1387.01
# 4  2295902490203259134  2273948311742316796             30    311   462.94
#
#    month  day  year
# 0      4   24  2020
# 1      4   24  2020
# 2      4   26  2020
# 3      4   26  2020
# 4      4   26  2020

# %%
ecom_df_cleaned = ecom_df_cleaned[ecom_df_cleaned['price'] > 0]

# %%
X = ecom_df_cleaned

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
scaler = StandardScaler()
scaled_X = scaler.fit_transform(X)

# %%
scaled_X_df = pd.DataFrame(data=scaled_X, columns=X.columns)

# %%
scaled_X_df.head()
# Out:
#    order_id  product_id  category_code     brand     price     month  \
# 0 -3.908141   -0.514326       0.910582  0.802938 -0.130424 -0.597876
# 1 -3.903323    1.909656       0.667268 -0.446382 -0.451761 -0.597876
# 2 -3.830421   -0.514326       1.214726  0.018481 -0.597007 -0.597876
# 3 -3.829041   -0.514326       0.880168 -1.672458  4.528568 -0.597876
# 4 -3.819766    1.909656      -0.883862 -0.051248  1.014091 -0.597876
#
#         day  year
# 0  0.963213   0.0
# 1  0.963213   0.0
# 2  1.192712   0.0
# 3  1.192712   0.0
# 4  1.192712   0.0

# %%
inertia = []
for n_clusters in range(1, 7):
    kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(scaled_X_df)
    inertia.append(kmeans.inertia_ / n_clusters)
inertias = pd.DataFrame({'n_clusters': range(1, 7), 'inertia': inertia})
ax = inertias.plot(x='n_clusters', y='inertia')
plt.xlabel('Number of clusters(k)')
plt.ylabel('Average Within-Cluster Squared Distances')
plt.ylim((0, 1.1 * inertias.inertia.max()))
ax.legend().set_visible(False)
plt.show()
# Out:
# /Users/vibha/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/vibha/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/vibha/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/vibha/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/vibha/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/vibha/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
model = KMeans(n_clusters=3, random_state=33)

# %%
cluster_labels = model.fit_predict(scaled_X)
# Out:
# /Users/vibha/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
X['Cluster'] = cluster_labels

# %%
X.head()
# Out:
#               order_id           product_id  category_code  brand    price  \
# 0  2294359932054536986  1515966223509089906             89    458   162.01
# 1  2294444024058086220  2273948319057183658             81    243    77.52
# 2  2295716521449619559  1515966223509261697             99    323    39.33
# 3  2295740594749702229  1515966223509104892             88     32  1387.01
# 4  2295902490203259134  2273948311742316796             30    311   462.94
#
#    month  day  year  Cluster
# 0      4   24  2020        1
# 1      4   24  2020        0
# 2      4   26  2020        1
# 3      4   26  2020        1
# 4      4   26  2020        0

# %%
X.corr()['Cluster'].sort_values(ascending=False)
# Out:
# Cluster          1.000000
# order_id         0.502533
# month            0.445733
# price            0.126404
# category_code    0.059709
# day              0.018426
# brand           -0.033600
# product_id      -0.782517
# year                  NaN
# Name: Cluster, dtype: float64

# %%
# Decode Features After Clustering
X['category_code'] = label_encoder_category.inverse_transform(X['category_code'])
X['brand'] = label_encoder_brand.inverse_transform(X['brand'])

# %%
X.head()
# Out:
#               order_id           product_id                     category_code  \
# 0  2294359932054536986  1515966223509089906                electronics.tablet
# 1  2294444024058086220  2273948319057183658       electronics.audio.headphone
# 2  2295716521449619559  1515966223509261697           furniture.kitchen.table
# 3  2295740594749702229  1515966223509104892            electronics.smartphone
# 4  2295902490203259134  2273948311742316796  appliances.kitchen.refrigerators
#
#      brand    price  month  day  year  Cluster
# 0  samsung   162.01      4   24  2020        1
# 1   huawei    77.52      4   24  2020        0
# 2  maestro    39.33      4   26  2020        1
# 3    apple  1387.01      4   26  2020        1
# 4       lg   462.94      4   26  2020        0

# %%
cluster_summary = X.groupby('Cluster').agg({
    'price': ['count', 'mean', 'min', 'max'],  # Summary stats for price
    'category_code': lambda x: x.value_counts().head(5).to_dict(),  # Distribution of categories
    'brand': lambda x: x.value_counts().head(5).to_dict()  # Distribution of brands
}).reset_index()

cluster_summary.columns = ['Cluster', 'Total Products', 'Average Price', 'Min Price', 'Max Price', 
                           'Category Distribution', 'Brand Distribution']

print("\nCluster Summary:")
print(cluster_summary)
# Out:
# Cluster Summary:
#    Cluster  Total Products  Average Price  Min Price  Max Price  \
# 0        0          316503     155.871283       0.21    4166.64
# 1        1          766181     183.511925       0.02    6215.25
# 2        2          438710     247.809584       0.21   50925.90
#
#                                Category Distribution  \
# 0  {'electronics.smartphone': 43130, 'appliances....
# 1  {'electronics.smartphone': 184835, 'electronic...
# 2  {'electronics.smartphone': 121634, 'computers....
#
#                                   Brand Distribution
# 0  {'samsung': 58663, 'huawei': 22877, 'tefal': 1...
# 1  {'samsung': 159069, 'ava': 49884, 'tefal': 333...
# 2  {'samsung': 108907, 'apple': 32691, 'ava': 241...

# %%
for i in range(len(cluster_summary)):
    print(cluster_summary.iloc[i]['Category Distribution'])
    print('\n')
# Out:
# {'electronics.smartphone': 43130, 'appliances.environment.vacuum': 23778, 'appliances.kitchen.refrigerators': 21092, 'appliances.kitchen.kettle': 18402, 'electronics.video.tv': 16297}
#
#
# {'electronics.smartphone': 184835, 'electronics.video.tv': 36408, 'appliances.kitchen.refrigerators': 34843, 'electronics.audio.headphone': 34423, 'computers.notebook': 34370}
#
#
# {'electronics.smartphone': 121634, 'computers.notebook': 25044, 'appliances.kitchen.refrigerators': 20433, 'electronics.video.tv': 18272, 'electronics.audio.headphone': 18221}

# %%
for i in range(len(cluster_summary)):
    print(cluster_summary.iloc[i]['Brand Distribution'])
    print('\n')
# Out:
# {'samsung': 58663, 'huawei': 22877, 'tefal': 12568, 'polaris': 10063, 'lg': 9588}
#
#
# {'samsung': 159069, 'ava': 49884, 'tefal': 33396, 'apple': 31477, 'lg': 26553}
#
#
# {'samsung': 108907, 'apple': 32691, 'ava': 24156, 'lg': 17816, 'tefal': 17410}

# %%
ecom_df_cleaned.head()
# Out:
#               order_id           product_id                     category_code  \
# 0  2294359932054536986  1515966223509089906                electronics.tablet
# 1  2294444024058086220  2273948319057183658       electronics.audio.headphone
# 2  2295716521449619559  1515966223509261697           furniture.kitchen.table
# 3  2295740594749702229  1515966223509104892            electronics.smartphone
# 4  2295902490203259134  2273948311742316796  appliances.kitchen.refrigerators
#
#      brand    price  month  day  year  Cluster
# 0  samsung   162.01      4   24  2020        1
# 1   huawei    77.52      4   24  2020        0
# 2  maestro    39.33      4   26  2020        1
# 3    apple  1387.01      4   26  2020        1
# 4       lg   462.94      4   26  2020        0

# %% [markdown]
# ### Hierarchial Clustering

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
ecom_df_cleaned = pd.read_csv('purchase_data_cleaned2.csv')

# dropping the event_time column because we've already extracted the month, year and day from it. 
ecom_df_cleaned = ecom_df_cleaned.drop(['event_time'], axis=1)

# converting categorical columns into numerical. We can also drop category_id column since the id's are duplicated and seem odd
ecom_df_cleaned = ecom_df_cleaned.drop(['category_id'], axis=1)

ecom_df_cleaned = ecom_df_cleaned[ecom_df_cleaned['price'] > 0]

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder_category = LabelEncoder()
label_encoder_brand = LabelEncoder()

# Apply Label Encoding
ecom_df_cleaned['category_code'] = label_encoder_category.fit_transform(ecom_df_cleaned['category_code'])
ecom_df_cleaned['brand'] = label_encoder_brand.fit_transform(ecom_df_cleaned['brand'])

# %%
ecom_df_cleaned.head()
# Out:
#               order_id           product_id  category_code  brand    price  \
# 0  2294359932054536986  1515966223509089906             89    458   162.01
# 1  2294444024058086220  2273948319057183658             81    243    77.52
# 2  2295716521449619559  1515966223509261697             99    323    39.33
# 3  2295740594749702229  1515966223509104892             88     32  1387.01
# 4  2295902490203259134  2273948311742316796             30    311   462.94
#
#    month  day  year
# 0      4   24  2020
# 1      4   24  2020
# 2      4   26  2020
# 3      4   26  2020
# 4      4   26  2020

# %%
X2 = ecom_df_cleaned.copy()

# %%
scaler = StandardScaler()
X2_norm = scaler.fit_transform(X2)
X2_norm_df = pd.DataFrame(data=X2_norm, columns=X2.columns)

# %%
X2_norm_df.head()
# Out:
#    order_id  product_id  category_code     brand     price     month  \
# 0 -3.908141   -0.514326       0.910582  0.802938 -0.130424 -0.597876
# 1 -3.903323    1.909656       0.667268 -0.446382 -0.451761 -0.597876
# 2 -3.830421   -0.514326       1.214726  0.018481 -0.597007 -0.597876
# 3 -3.829041   -0.514326       0.880168 -1.672458  4.528568 -0.597876
# 4 -3.819766    1.909656      -0.883862 -0.051248  1.014091 -0.597876
#
#         day  year
# 0  0.963213   0.0
# 1  0.963213   0.0
# 2  1.192712   0.0
# 3  1.192712   0.0
# 4  1.192712   0.0

# %%
sampled_data = X2_norm_df.sample(n=10000, random_state=33)

# %%
Z = linkage(sampled_data, method='complete')

# %%
plt.figure(figsize=(10, 5))
dendrogram(
    Z,
    truncate_mode='lastp',
    p=10,
    leaf_rotation=90,
    leaf_font_size=10,
    show_contracted=True
)
plt.title("Dendrogram")
plt.xlabel("Cluster")
plt.ylabel("Distance")
plt.show()

# %%
Z = linkage(sampled_data, method='ward')

plt.figure(figsize=(10, 5))
dendrogram(
    Z,
    truncate_mode='lastp',
    p=10,
    leaf_rotation=90,
    leaf_font_size=10,
    show_contracted=True
)
plt.title("Dendrogram")
plt.xlabel("Cluster")
plt.ylabel("Distance")
plt.show()

# %% [markdown]
# We can see 2 major groups of clusters being formed when linkage is complete and 3 major clusters when linkage is ward

# %%
from sklearn.cluster import Birch
from sklearn.cluster import AgglomerativeClustering

# %%
from sklearn.cluster import Birch

birch_model = Birch(n_clusters=2)

cluster_labels = birch_model.fit_predict(X2_norm_df)

# %%
# Add cluster labels to the dataset
X2['Cluster'] = cluster_labels

# %%
X2.head()
# Out:
#               order_id           product_id  category_code  brand    price  \
# 0  2294359932054536986  1515966223509089906             89    458   162.01
# 1  2294444024058086220  2273948319057183658             81    243    77.52
# 2  2295716521449619559  1515966223509261697             99    323    39.33
# 3  2295740594749702229  1515966223509104892             88     32  1387.01
# 4  2295902490203259134  2273948311742316796             30    311   462.94
#
#    month  day  year  Cluster
# 0      4   24  2020        1
# 1      4   24  2020        1
# 2      4   26  2020        1
# 3      4   26  2020        1
# 4      4   26  2020        1

# %%
# Decode Features After Clustering
X2['category_code'] = label_encoder_category.inverse_transform(X2['category_code'])
X2['brand'] = label_encoder_brand.inverse_transform(X2['brand'])

# %%
cluster_summary = X2.groupby('Cluster').agg({
    'price': ['count', 'mean', 'min', 'max'],  # Summary stats for price
    'category_code': lambda x: x.value_counts().head(5).to_dict(),  # Distribution of categories
    'brand': lambda x: x.value_counts().head(5).to_dict()  # Distribution of brands
}).reset_index()

cluster_summary.columns = ['Cluster', 'Total Products', 'Average Price', 'Min Price', 'Max Price', 
                           'Category Distribution', 'Brand Distribution']

print("\nCluster Summary:")
print(cluster_summary)
# Out:
# Cluster Summary:
#    Cluster  Total Products  Average Price  Min Price  Max Price  \
# 0        0           67425     954.828323      53.22   50925.90
# 1        1         1453969     161.127453       0.02    1504.61
#
#                                Category Distribution  \
# 0  {'electronics.smartphone': 31034, 'computers.n...
# 1  {'electronics.smartphone': 318565, 'appliances...
#
#                                   Brand Distribution
# 0  {'apple': 28454, 'samsung': 15841, 'asus': 585...
# 1  {'samsung': 310798, 'ava': 81353, 'tefal': 633...

# %%
for i in range(len(cluster_summary)):
    print(cluster_summary.iloc[i]['Category Distribution'])
    print('\n')
# Out:
# {'electronics.smartphone': 31034, 'computers.notebook': 13335, 'appliances.kitchen.refrigerators': 6833, 'electronics.video.tv': 6742, 'electronics.audio.headphone': 1776}
#
#
# {'electronics.smartphone': 318565, 'appliances.kitchen.refrigerators': 69535, 'appliances.environment.vacuum': 65470, 'electronics.video.tv': 64235, 'electronics.audio.headphone': 62942}

# %%
for i in range(len(cluster_summary)):
    print(cluster_summary.iloc[i]['Brand Distribution'])
    print('\n')
# Out:
# {'apple': 28454, 'samsung': 15841, 'asus': 5852, 'lg': 4450, 'lenovo': 3225}
#
#
# {'samsung': 310798, 'ava': 81353, 'tefal': 63373, 'huawei': 52819, 'lg': 49507}

# %%
X3 = ecom_df_cleaned.copy()

# %%
scaler = StandardScaler()
X3_norm = scaler.fit_transform(X3)
X3_norm_df = pd.DataFrame(data=X3_norm, columns=X3.columns)

# %%
birch_model2 = Birch(n_clusters=3)

cluster_labels2 = birch_model2.fit_predict(X3_norm_df)

# %%
# Add cluster labels to the dataset
X3['Cluster'] = cluster_labels2

# %%
# Decode Features After Clustering
X3['category_code'] = label_encoder_category.inverse_transform(X3['category_code'])
X3['brand'] = label_encoder_brand.inverse_transform(X3['brand'])

# %%
X3.head()
# Out:
#               order_id           product_id                     category_code  \
# 0  2294359932054536986  1515966223509089906                electronics.tablet
# 1  2294444024058086220  2273948319057183658       electronics.audio.headphone
# 2  2295716521449619559  1515966223509261697           furniture.kitchen.table
# 3  2295740594749702229  1515966223509104892            electronics.smartphone
# 4  2295902490203259134  2273948311742316796  appliances.kitchen.refrigerators
#
#      brand    price  month  day  year  Cluster
# 0  samsung   162.01      4   24  2020        1
# 1   huawei    77.52      4   24  2020        1
# 2  maestro    39.33      4   26  2020        1
# 3    apple  1387.01      4   26  2020        1
# 4       lg   462.94      4   26  2020        1

# %%
cluster_summary = X3.groupby('Cluster').agg({
    'price': ['count', 'mean', 'min', 'max'],  # Summary stats for price
    'category_code': lambda x: x.value_counts().head(5).to_dict(),  # Distribution of categories
    'brand': lambda x: x.value_counts().head(5).to_dict()  # Distribution of brands
}).reset_index()

cluster_summary.columns = ['Cluster', 'Total Products', 'Average Price', 'Min Price', 'Max Price', 
                           'Category Distribution', 'Brand Distribution']

print("\nCluster Summary:")
print(cluster_summary)
# Out:
# Cluster Summary:
#    Cluster  Total Products  Average Price  Min Price  Max Price  \
# 0        0           67424     954.087177      53.22   11574.05
# 1        1         1453969     161.127453       0.02    1504.61
# 2        2               1   50925.900000   50925.90   50925.90
#
#                                Category Distribution  \
# 0  {'electronics.smartphone': 31034, 'computers.n...
# 1  {'electronics.smartphone': 318565, 'appliances...
# 2                        {'electronics.video.tv': 1}
#
#                                   Brand Distribution
# 0  {'apple': 28454, 'samsung': 15840, 'asus': 585...
# 1  {'samsung': 310798, 'ava': 81353, 'tefal': 633...
# 2                                     {'samsung': 1}

# %%
for i in range(len(cluster_summary)):
    print(cluster_summary.iloc[i]['Category Distribution'])
    print('\n')
# Out:
# {'electronics.smartphone': 31034, 'computers.notebook': 13335, 'appliances.kitchen.refrigerators': 6833, 'electronics.video.tv': 6741, 'electronics.audio.headphone': 1776}
#
#
# {'electronics.smartphone': 318565, 'appliances.kitchen.refrigerators': 69535, 'appliances.environment.vacuum': 65470, 'electronics.video.tv': 64235, 'electronics.audio.headphone': 62942}
#
#
# {'electronics.video.tv': 1}

# %%
for i in range(len(cluster_summary)):
    print(cluster_summary.iloc[i]['Brand Distribution'])
    print('\n')
# Out:
# {'apple': 28454, 'samsung': 15840, 'asus': 5852, 'lg': 4450, 'lenovo': 3225}
#
#
# {'samsung': 310798, 'ava': 81353, 'tefal': 63373, 'huawei': 52819, 'lg': 49507}
#
#
# {'samsung': 1}

# %%
X3[X3['price'] == 50925.90]
# Out:
#                    order_id           product_id         category_code  \
# 614023  2353234364520727464  1515966223509105016  electronics.video.tv
#
#           brand    price  month  day  year  Cluster
# 614023  samsung  50925.9      5   26  2020        2

# %%
cluster_summary
# Out:
#    Cluster  Total Products  Average Price  Min Price  Max Price  \
# 0        0           67424     954.087177      53.22   11574.05
# 1        1         1453969     161.127453       0.02    1504.61
# 2        2               1   50925.900000   50925.90   50925.90
#
#                                Category Distribution  \
# 0  {'electronics.smartphone': 31034, 'computers.n...
# 1  {'electronics.smartphone': 318565, 'appliances...
# 2                        {'electronics.video.tv': 1}
#
#                                   Brand Distribution
# 0  {'apple': 28454, 'samsung': 15840, 'asus': 585...
# 1  {'samsung': 310798, 'ava': 81353, 'tefal': 633...
# 2                                     {'samsung': 1}

# %%
# Convert Category Distribution into a long-form DataFrame
cat_rows = []
for i, row in cluster_summary.iterrows():
    cluster_id = row['Cluster']
    cat_dist = row['Category Distribution']
    for cat, count in cat_dist.items():
        cat_rows.append({'Cluster': cluster_id, 'Category': cat, 'Count': count})

cat_df = pd.DataFrame(cat_rows)

# Convert Brand Distribution into a long-form DataFrame
brand_rows = []
for i, row in cluster_summary.iterrows():
    cluster_id = row['Cluster']
    brand_dist = row['Brand Distribution']
    for brand, count in brand_dist.items():
        brand_rows.append({'Cluster': cluster_id, 'Brand': brand, 'Count': count})

brand_df = pd.DataFrame(brand_rows)

# %%
# Plot Category Distribution separately for each cluster
for cluster_id in cat_df['Cluster'].unique():
    cluster_data = cat_df[cat_df['Cluster'] == cluster_id].copy()
    plt.figure(figsize=(8,5))
    # Sort categories by count for a nicer plot
    cluster_data = cluster_data.sort_values('Count', ascending=False)
    sns.barplot(x='Category', y='Count', data=cluster_data, color='skyblue')
    plt.title(f'Category Distribution - Cluster {cluster_id}')
    plt.xlabel('Category')
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# %%
# Plot Brand Distribution separately for each cluster
for cluster_id in brand_df['Cluster'].unique():
    cluster_data = brand_df[brand_df['Cluster'] == cluster_id].copy()
    plt.figure(figsize=(8,5))
    # Sort brands by count for a nicer plot
    cluster_data = cluster_data.sort_values('Count', ascending=False)
    sns.barplot(x='Brand', y='Count', data=cluster_data, color='lightgreen')
    plt.title(f'Brand Distribution - Cluster {cluster_id}')
    plt.xlabel('Brand')
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Association Rule Mining

# %%
# pip install apyori
# !pip install mlxtend
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
ecom_df_cleaned = pd.read_csv('purchase_data_cleaned2.csv')

# dropping the event_time column because we've already extracted the month, year and day from it. 
ecom_df_cleaned = ecom_df_cleaned.drop(['event_time'], axis=1)

# converting categorical columns into numerical. We can also drop category_id column since the id's are duplicated and seem odd
ecom_df_cleaned = ecom_df_cleaned.drop(['category_id'], axis=1)

ecom_df_cleaned = ecom_df_cleaned[ecom_df_cleaned['price'] > 0]

# %%
ecom_df_cleaned.head()
# Out:
#               order_id           product_id                     category_code  \
# 0  2294359932054536986  1515966223509089906                electronics.tablet
# 1  2294444024058086220  2273948319057183658       electronics.audio.headphone
# 2  2295716521449619559  1515966223509261697           furniture.kitchen.table
# 3  2295740594749702229  1515966223509104892            electronics.smartphone
# 4  2295902490203259134  2273948311742316796  appliances.kitchen.refrigerators
#
#      brand    price  month  day  year
# 0  samsung   162.01      4   24  2020
# 1   huawei    77.52      4   24  2020
# 2  maestro    39.33      4   26  2020
# 3    apple  1387.01      4   26  2020
# 4       lg   462.94      4   26  2020

# %%
ecom_df_cleaned['item'] = ecom_df_cleaned['category_code'] + "_" + ecom_df_cleaned['brand']

# %%
ecom_df_cleaned.head()
# Out:
#               order_id           product_id                     category_code  \
# 0  2294359932054536986  1515966223509089906                electronics.tablet
# 1  2294444024058086220  2273948319057183658       electronics.audio.headphone
# 2  2295716521449619559  1515966223509261697           furniture.kitchen.table
# 3  2295740594749702229  1515966223509104892            electronics.smartphone
# 4  2295902490203259134  2273948311742316796  appliances.kitchen.refrigerators
#
#      brand    price  month  day  year                                 item
# 0  samsung   162.01      4   24  2020           electronics.tablet_samsung
# 1   huawei    77.52      4   24  2020   electronics.audio.headphone_huawei
# 2  maestro    39.33      4   26  2020      furniture.kitchen.table_maestro
# 3    apple  1387.01      4   26  2020         electronics.smartphone_apple
# 4       lg   462.94      4   26  2020  appliances.kitchen.refrigerators_lg

# %%
# Group by order_id and get the list of products in each order
transactions = ecom_df_cleaned.groupby('order_id')['item'].apply(list).values.tolist()

# Convert to a format suitable for Apriori algorithm
te = TransactionEncoder()
te_ary = te.fit_transform(transactions)
df_trans = pd.DataFrame(te_ary, columns=te.columns_)

# %%
# Apply Apriori algorithm to find frequent itemsets
frequent_itemsets = apriori(df_trans, min_support=0.002, use_colnames=True)

# Generate association rules (including num_itemsets argument)
# In older versions, num_itemsets is required (this can be set to the number of itemsets you're analyzing)
num_itemsets = len(frequent_itemsets)

# Generate association rules
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.2, num_itemsets=num_itemsets)

# Print the rules
print(rules)

# %%
frequent_itemsets

# %%
rules

# %%
def recommend_items(rules, input_items, top_n=5):
    recommendations = []

    for item in input_items:
        relevant_rules = rules[rules['antecedents'].apply(lambda x: item in x)]
        relevant_rules = relevant_rules.sort_values(by='confidence', ascending=False)
        
        for consequent in relevant_rules['consequents'].head(top_n):
            recommendations.extend(list(consequent))
    
    return list(set(recommendations))

# %%
# Example recommendation
input_items = ['electronics.smartphone_awax']
recommended_items = recommend_items(rules, input_items, top_n=3)
print("Recommended items:", recommended_items)

# %%
# Apply Apriori algorithm to find frequent itemsets
frequent_itemsets = apriori(df_trans, min_support=0.002, use_colnames=True)

# Generate association rules (including num_itemsets argument)
# In older versions, num_itemsets is required (this can be set to the number of itemsets you're analyzing)
num_itemsets = len(frequent_itemsets)

# Generate association rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=0.1, num_itemsets=num_itemsets)

# Print the rules
print(rules)

# %%
rules

# %%
# Example recommendation
input_items = ['electronics.smartphone_samsung']
recommended_items = recommend_items(rules, input_items, top_n=3)
print("Recommended items:", recommended_items)
